# %% [markdown]
# ## Linking without deduplication
#
# A simple record linkage model using the `link_only` [link type](https://moj-analytical-services.github.io/splink/settings_dict_guide.html#link_type).

# %%
import pandas as pd 
df_l = pd.read_parquet("./data/fake_df_l.parquet")
df_r = pd.read_parquet("./data/fake_df_r.parquet")
df_l.head(2)
# Out:
#    unique_id first_name surname         dob    city  \
# 0          0     Julia     None  2015-10-29  London
# 1          4       oNah  Watson  2008-03-23  Bolton
#
#                             email  group
# 0             hannah88@powers.com      0
# 1  matthew78@ballard-mcdonald.net      1

# %%
from splink.duckdb.duckdb_linker import DuckDBLinker
from splink.duckdb import duckdb_comparison_library as cl
settings = {
    "link_type": "link_only",
    "blocking_rules_to_generate_predictions": [
        "l.first_name = r.first_name",
        "l.surname = r.surname",
    ],
    "comparisons": [
        cl.levenshtein_at_thresholds("first_name", 2),
        cl.levenshtein_at_thresholds("surname"),
        cl.levenshtein_at_thresholds("dob"),
        cl.exact_match("city", term_frequency_adjustments=True),
        cl.levenshtein_at_thresholds("email"),
    ],       
}

# %%
linker = DuckDBLinker([df_l, df_r], settings, input_table_aliases=["df_left", "df_right"])
deterministic_rules = [
    "l.first_name = r.first_name and levenshtein(r.dob, l.dob) <= 1",
    "l.surname = r.surname and levenshtein(r.dob, l.dob) <= 1",
    "l.first_name = r.first_name and levenshtein(r.surname, l.surname) <= 2",
    "l.email = r.email"
]

linker.estimate_probability_two_random_records_match(deterministic_rules, recall=0.7)
# Out:
# Probability two random records match is estimated to be  0.00582.
# This means that amongst all possible pairwise record comparisons, one in 171.80 are expected to match.  With 148,239 total possible comparisons, we expect a total of around 862.86 matching pairs

# %%
linker.estimate_u_using_random_sampling(target_rows=1e6)
# Out:
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - first_name (no m values are trained).
#     - surname (no m values are trained).
#     - dob (no m values are trained).
#     - city (no m values are trained).
#     - email (no m values are trained).

# %%
session_dob = linker.estimate_parameters_using_expectation_maximisation("l.dob = r.dob")
session_email = linker.estimate_parameters_using_expectation_maximisation("l.email = r.email")
# Out:
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.dob = r.dob
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name
#     - surname
#     - city
#     - email
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - dob
#
# Iteration 1: Largest change in params was 0.435 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.0642 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.0233 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.0113 in probability_two_random_records_match
# Iteration 5: Largest change in params was 0.00638 in probability_two_random_records_match
# Iteration 6: Largest change in params was 0.00395 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.0026 in probability_two_random_records_match
# Iteration 8: Largest change in params was 0.00178 in probability_two_random_records_match
# Iteration 9: Largest change in params was 0.00126 in probability_two_random_records_match
# Iteration 10: Largest change in params was 0.000904 in probability_two_random_records_match
# Iteration 11: Largest change in params was 0.000661 in probability_two_random_records_match
# Iteration 12: Largest change in params was 0.000488 in probability_two_random_records_match
# Iteration 13: Largest change in params was 0.000364 in probability_two_random_records_match
# Iteration 14: Largest change in params was 0.000272 in probability_two_random_records_match
# Iteration 15: Largest change in params was 0.000205 in probability_two_random_records_match
# Iteration 16: Largest change in params was 0.000155 in probability_two_random_records_match
# Iteration 17: Largest change in params was 0.000117 in probability_two_random_records_match
# Iteration 18: Largest change in params was 8.91e-05 in probability_two_random_records_match
#
# EM converged after 18 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l.email = r.email
#
# Parameter estimates will be made for the following comparison(s):
#     - first_name
#     - surname
#     - dob
#     - city
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - email
#
# Iteration 1: Largest change in params was 0.489 in probability_two_random_records_match
# Iteration 2: Largest change in params was 0.046 in probability_two_random_records_match
# Iteration 3: Largest change in params was 0.0149 in probability_two_random_records_match
# Iteration 4: Largest change in params was 0.00699 in probability_two_random_records_match
# Iteration 5: Largest change in params was 0.00392 in probability_two_random_records_match
# Iteration 6: Largest change in params was 0.00246 in probability_two_random_records_match
# Iteration 7: Largest change in params was 0.00166 in probability_two_random_records_match
# Iteration 8: Largest change in params was 0.00119 in probability_two_random_records_match
# Iteration 9: Largest change in params was 0.000888 in probability_two_random_records_match
# Iteration 10: Largest change in params was 0.000682 in probability_two_random_records_match
# Iteration 11: Largest change in params was 0.000537 in probability_two_random_records_match
# Iteration 12: Largest change in params was 0.000432 in probability_two_random_records_match
# Iteration 13: Largest change in params was 0.000352 in probability_two_random_records_match
# Iteration 14: Largest change in params was 0.000291 in probability_two_random_records_match
# Iteration 15: Largest change in params was 0.000243 in probability_two_random_records_match
# Iteration 16: Largest change in params was 0.000205 in probability_two_random_records_match
# Iteration 17: Largest change in params was 0.000175 in probability_two_random_records_match
# Iteration 18: Largest change in params was 0.00015 in probability_two_random_records_match
# Iteration 19: Largest change in params was 0.000129 in probability_two_random_records_match
# Iteration 20: Largest change in params was 0.000112 in probability_two_random_records_match
# Iteration 21: Largest change in params was 9.7e-05 in probability_two_random_records_match
#
# EM converged after 21 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values

# %%
results = linker.predict(threshold_match_probability=0.9)

# %%
results.as_pandas_dataframe(limit=8)
# Out:
#    match_weight  match_probability source_dataset_l  unique_id_l  \
# 0      4.875529           0.967056          df_left            0
# 1      4.875529           0.967056          df_left            0
# 2      4.840945           0.966284          df_left           27
# 3     15.216486           0.999974          df_left           32
# 4     18.083420           0.999996          df_left           38
# 5     14.026676           0.999940          df_left           38
# 6     18.083420           0.999996          df_left           38
# 7      9.296220           0.998412          df_left           38
#
#   source_dataset_r  unique_id_r first_name_l first_name_r  gamma_first_name  \
# 0         df_right            1       Julia        Julia                  2
# 1         df_right            2       Julia        Julia                  2
# 2         df_right           28     Matilda      Matilda                  2
# 3         df_right           34       Baxter       Baxter                 2
# 4         df_right           39      Olivia       Olivia                  2
# 5         df_right           40      Olivia       Olivia                  2
# 6         df_right           41      Olivia       Olivia                  2
# 7         df_right           42      Olivia       Olivia                  2
#
#   surname_l  ...       dob_l       dob_r gamma_dob  city_l  city_r gamma_city  \
# 0       NaN  ...  2015-10-29  2015-07-31         0  London  London          1
# 1       NaN  ...  2015-10-29  2016-01-27         0  London  London          1
# 2     Hsrir  ...  1983-04-30  1983-04-30         3  London  London          1
# 3     Aria   ...  1992-09-07  1992-09-30         1  London  London          1
# 4   Andrews  ...  2009-01-23  2009-01-23         3     NaN  London         -1
# 5   Andrews  ...  2009-01-23  2009-03-24         1     NaN  London         -1
# 6   Andrews  ...  2009-01-23  2009-01-23         3     NaN  London         -1
# 7   Andrews  ...  2009-01-23  2009-01-23         3     NaN  London         -1
#
#                             email_l                           email_r  \
# 0               hannah88@powers.com               hannah88@powers.com
# 1               hannah88@powers.com               hannah88@powers.com
# 2               patrcio47@davis.cam              patricia47@davis.com
# 3       christineshepherd@allen.com       christineshepherd@allen.com
# 4  hesterkurt@taylor-fitzgerald.com  hesterkurt@taylor-fitzgerald.com
# 5  hesterkurt@taylor-fitzgerald.com  hesterkurt@taylor-fitzgerald.com
# 6  hesterkurt@taylor-fitzgerald.com  hesterkurt@taylor-fitzgerald.com
# 7  hesterkurt@taylor-fitzgerald.com   hesterkuot@taylrr-fitzgeraldcom
#
#   gamma_email match_key
# 0           3         0
# 1           3         0
# 2           0         0
# 3           3         0
# 4           3         0
# 5           3         0
# 6           3         0
# 7           0         0
#
# [8 rows x 22 columns]
# Bad pipe message: %s [b't\xf9D\x11\xc7+D\x99\x9f\xec\xcd\x96\xfby8D\xf9\xc0 \xa7\xaa:u\x16_G\x07\xc0\xb9\xad\x8e\xe5\xc1\x00\\\xbd']
# Bad pipe message: %s [b"yY\xa3pV0]\x06\x83nJ\xdf\xaf'8E\xfc\xf6 \xdc\xde\xa27\x02]&\xd2\x0b\x9cN\xe4\x8d\xae8\xd2\xa6L\xabaRF\x9d\xc4\xab%{\xf5\xa5\x9eS\t\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 +\xb7\xa1Z\x01JT\xf8P\xa7ag90eVL\xfa>\xa1^W"]
# Bad pipe message: %s [b"\xf2\xa3&.\x83\xe7\xbb\xf8/\x11(vs\xf47\x02\xdc\x1b\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04"]
# Bad pipe message: %s [b'\x08\x06\x04\x01\x05\x01\x06', b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'\xfd\xf3']
# Bad pipe message: %s [b"\xc2\x00\x0b\xca\x97\x8e\x7fr9\xeb\xc6\xf6Lm\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0", b'\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00']
# Bad pipe message: %s [b'\xa7\xe7\x15\t\x02\xb4\\\x9d\xea\x14\xea\xe6k\xf23\xf7\xaf\x1a\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00']
# Bad pipe message: %s [b'\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08']
# Bad pipe message: %s [b'@\xe5\x92\x052buy\x86w\xef\x94\xa1\xee\xddTJ\xc2\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c']
# Bad pipe message: %s [b'\x0f\x8aPZ\xf0\xcd\xe7\x92\xf8\xb9\xaf\xb0=\xa6X\x9f0\x17\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00']
# Bad pipe message: %s [b'\xc3\xb4<\xa0^\xbc\x99y\xb4o\xcd\x08-\x86{\xcb\x82:\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0']
# Bad pipe message: %s [b'\x05']
# Bad pipe message: %s [b'{_\xfe\x97\xd0\x8e\xdf\xe7\x99f\x06\xd8\xbep\xb9S]\xf0\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0']
# Bad pipe message: %s [b"&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>"]
